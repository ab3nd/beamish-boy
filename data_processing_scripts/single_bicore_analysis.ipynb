# %%
import csv
import matplotlib.pyplot as plt

with open("../data/unlinked_bicores/5Msample_1MHz_power_on_2_stripped.csv", 'r') as infile:
    reader = csv.DictReader(infile)
    times = []
    logic0 = []
    logic1 = []
    for entry in reader:
        times.append(entry["microseconds"])
        logic0.append(entry["logic0"])
        logic1.append(entry["logic1"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_701420/3602318109.py in <module>
#       1 import csv
# ----> 2 from matplotlib import plt
#       3
#       4 with open("../data/unlinked_bicores/5Msample_1MHz_power_on_2_stripped.csv", 'r') as infile:
#       5     reader = csv.DictReader(infile)
#
# ImportError: cannot import name 'plt' from 'matplotlib' (/usr/lib/python3/dist-packages/matplotlib/__init__.py)
